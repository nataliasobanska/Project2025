# %% [markdown]
# ## DATA ANALYTICS NOTEBOOK
#
# This notebook is created for learning, noting and prototyping purposes that will be later used in the application.
#
# 1. Importing Data
#
# 2. Descriptive Analytics
#
# 3. Diagnostic Analytics
#
# 4. Predictive Analytics
#
# 5. Prescriptive Analytics

# %%
# libraries import
import pandas as pd
import kagglehub
import os

# %% [markdown]
# ## The Dataset - Google Stock Market Data
#
# The dataset is imported from kaggle. The description attached below:
#
#     This data is collected from Yahoo Finance 2024
#
#     Price: Close price of the stock
#     1. Volume: Volume of the stock
#     2. Date: Date of the stock
#     3. Open: Open price of the stock
#     4. High: High price of the stock
#     5. Low: Low price of the stock
#     6. Close: Close price of the stock
#     7. Adj Close: Adjusted close price of the stock
#     8. Ticker: Ticker symbol of the stock

# %%
#--- dataset import
path = kagglehub.dataset_download("itzusama/google-stock-market-data-2024")
dataFileName = 'GOOG.csv' 
dataPath = os.path.join(path, dataFileName)

#--- data frame
df = pd.read_csv(dataPath)
df
# Out:
# ...
#           Price           Adj Close               Close                High  \
# 0        Ticker                GOOG                GOOG                GOOG
# 1    2024-01-02  139.21810913085938  139.55999755859375  140.61500549316406
# 2    2024-01-03  140.01614379882812  140.36000061035156  141.08999633789062
# 3    2024-01-04   137.7018280029297   138.0399932861328  140.63499450683594
# 4    2024-01-05   137.0534210205078  137.38999938964844  138.80999755859375
# ..          ...                 ...                 ...                 ...
# 229  2024-11-26   170.6199951171875   170.6199951171875   171.4949951171875
# 230  2024-11-27  170.82000732421875  170.82000732421875  171.13999938964844
# 231  2024-11-29  170.49000549316406  170.49000549316406   170.8699951171875
# 232  2024-12-02  172.97999572753906  172.97999572753906  173.60000610351562
# 233  2024-12-03  173.02000427246094  173.02000427246094  174.32000732421875
#
#                     Low                Open    Volume
# ...

# %%
print('Labels',df.columns)
print('Size', df.shape)
# Out:
# Labels Index(['Price', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Size (234, 7)
